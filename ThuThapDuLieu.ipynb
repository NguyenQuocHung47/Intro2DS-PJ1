# %% [markdown]
# <div style="border:2px solid black; padding:10px;">
#     <h3>Nhóm 15</h3>
#     <h1 style='color:red;text-align:center;font-size:30px'>Chủ đề: Phân tích về doanh thu phim<b></b></h1>
# </div>

# %% [markdown]
# <h3>Danh sách thành viên</h3>
# <li> Nguyễn Quốc Hưng - 21120464 </li>
# <li> Đoàn Đức Hữu - 21120465 </li>
# <li> Võ Minh Khuê - 21120486</li>
# <li> Hồ Trọng Lễ - 21120494</li>

# %% [markdown]
# <h1 style='color:blue;text-align:center;font-size:30px'><b>Phần I - Thu thập dữ liệu</b></h1>

# %% [markdown]
# # Import thư viện

# %%
import pandas as pd

# %% [markdown]
# ## Thu nhập thông tin phim từ năm 1990 đến năm 2020

# %%
# !cd boxoffice_crawler/boxoffice_crawler/ && scrapy crawl BoxOfficeMojo

# %% [markdown]
# ### Đọc file dữ liệu

# %%
df = pd.read_csv(
    './boxoffice_crawler/boxoffice_crawler/boxoffice_1990_2022.csv', encoding='latin1')
df.head(20)
# Out:
#                                title domestic_revenue world_revenue  \
# 0                     Batman Returns     $162,831,698  $266,831,698
# 1                     Coupe de Ville         $715,983      $715,983
# 2                       C'est la vie         $805,472      $805,472
# 3              Waiting for the Light         $808,690      $808,690
# 4          Atlantis: The Lost Empire      $84,056,472  $186,053,725
# 5                          Evolution      $38,345,494   $98,376,292
# 6                            Jumanji     $100,475,249  $100,475,249
# 7             The American President      $60,079,496   $60,079,496
# 8                   Mulholland Drive       $7,220,243   $20,117,339
# 9                          Tombstone      $56,505,065   $56,505,065
# 10                   Heart and Souls      $16,589,540   $16,589,540
# 11          The Phantom of the Opera      $51,268,815  $154,648,887
# 12             The Brady Bunch Movie      $46,576,136   $46,576,136
# 13  Teenage Mutant Ninja Turtles III      $42,273,609   $42,273,609
# 14                          Hardball      $40,222,729   $44,102,389
# 15                        Supercross       $3,102,550    $3,344,431
# 16                   Life with Mikey      $12,440,858   $12,440,858
# 17                       Grizzly Man       $3,178,403    $4,061,305
# 18                              Rize       $3,336,391    $4,646,889
# 19                            Malena       $3,448,233   $14,493,284
#
#                             distributor opening_revenue opening_theaters  \
# 0                          Warner Bros.     $45,687,711            2,644
# 1                    Universal Pictures         $66,871                7
# 2            The Samuel Goldwyn Company         $18,749                2
# 3         Triumph Releasing Corporation        $334,748              149
# 4   Walt Disney Studios Motion Pictures        $329,011                2
# 5               DreamWorks Distribution     $13,408,351            2,611
# 6     Sony Pictures Entertainment (SPE)     $11,084,370            2,487
# 7     Sony Pictures Entertainment (SPE)     $10,014,558            1,508
# 8                    Universal Pictures        $587,591               66
# 9   Walt Disney Studios Motion Pictures      $6,454,752            1,504
# 10                   Universal Pictures      $4,322,250            1,275
# 11                         Warner Bros.      $4,001,890              622
# 12                   Paramount Pictures     $14,827,066            1,822
# 13                      New Line Cinema     $12,419,597            2,087
# 14                   Paramount Pictures      $9,386,342            2,137
# 15                Twentieth Century Fox      $1,330,520            1,621
# 16  Walt Disney Studios Motion Pictures      $3,606,279            1,366
# 17                     Lions Gate Films        $269,131               29
# 18                     Lions Gate Films      $1,574,787              352
# 19                              Miramax         $62,282               33
#
#           budget   MPAA                                            genres  \
# 0    $80,000,000  PG-13                              Action,Crime,Fantasy
# 1            NaN    NaN                                      Comedy,Drama
# 2            NaN    NaN                              Comedy,Drama,Romance
# 3            NaN    NaN                                            Comedy
# 4   $120,000,000     PG  Action,Adventure,Animation,Family,Fantasy,Sci-Fi
# 5    $80,000,000  PG-13                                     Comedy,Sci-Fi
# 6    $65,000,000     PG                   Adventure,Comedy,Family,Fantasy
# 7            NaN  PG-13                              Comedy,Drama,Romance
# 8            NaN      R                            Drama,Mystery,Thriller
# 9            NaN      R                   Biography,Drama,History,Western
# 10           NaN  PG-13                      Comedy,Drama,Fantasy,Romance
# 11   $70,000,000  PG-13                    Drama,Musical,Romance,Thriller
# 12           NaN  PG-13                                            Comedy
# 13   $21,000,000     PG     Action,Adventure,Comedy,Family,Fantasy,Sci-Fi
# 14   $32,000,000  PG-13                                Comedy,Drama,Sport
# 15           NaN  PG-13                        Action,Drama,Romance,Sport
# 16           NaN     PG                                     Comedy,Family
# 17           NaN      R                             Biography,Documentary
# 18           NaN  PG-13                                 Documentary,Music
# 19           NaN      R                                 Drama,Romance,War
#
#     running_time in_release release_date
# 0          126.0        196   19/06/1992
# 1           99.0        298   09/03/1990
# 2          110.0         63   02/11/1990
# 3           94.0         63   02/11/1990
# 4           95.0        210          NaN
# 5          101.0        207   08/06/2001
# 6          104.0        383   15/12/1995
# 7          114.0        411   17/11/1995
# 8          147.0        450   08/10/2001
# 9          130.0        373   24/12/1993
# 10         104.0        141   13/08/1993
# 11         143.0        375   22/12/2004
# 12          90.0        318   17/02/1995
# 13          96.0        288   19/03/1993
# 14         106.0        474   14/09/2001
# 15          80.0        137   17/08/2005
# 16          91.0        211   04/06/1993
# 17         103.0        147   12/08/2005
# 18          86.0        191   24/06/2005
# 19         108.0        375   22/12/2000
