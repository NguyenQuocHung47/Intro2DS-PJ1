# %% [markdown]
# <div style="border:2px solid black; padding:10px;">
#     <h3>Nhóm 15</h3>
#     <h1 style='color:red;text-align:center;font-size:30px'>Chủ đề: Phân tích về doanh thu phim<b></b></h1>
# </div>

# %% [markdown]
# <h3>Danh sách thành viên</h3>
# <li> Nguyễn Quốc Hưng - 21120464 </li>
# <li> Đoàn Đức Hữu - 21120465 </li>
# <li> Võ Minh Khuê - 21120486</li>
# <li> Hồ Trọng Lễ - 21120494</li>

# %% [markdown]
# <h1 style='color:blue;text-align:center;font-size:30px'><b>Phần I - A.Thu thập dữ liệu</b></h1>

# %% [markdown]
# # Import thư viện

# %%
import scrapy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Tạo Project với Scrapy

# %%
#!scrapy startproject boxoffice_crawler

# %% [markdown]
# ## Thu nhập thông tin phim từ năm 2000 đến năm 2020

# %%
# !cd boxoffice_crawler/boxoffice_crawler
# !scrapy crawl BoxOfficeMojo
# Out:
# c:\Users\dhuu2\OneDrive\Máy tính\MovieRevenue\Intro2DS-Project\boxoffice_crawler\boxoffice_crawler

# %% [markdown]
# ### Đọc file dữ liệu

# %%
df = pd.read_csv('./boxoffice2000_2022.csv', encoding='latin1')
df.head(20)
# Out:
#                                   title domestic_revenue   world_revenue  \
# 0                                Driven      $32,720,065     $54,744,738
# 1   What's the Worst That Could Happen?      $32,269,834     $38,464,131
# 2                            Supercross       $3,102,550      $3,344,431
# 3                      Land of the Lost      $49,438,370     $68,777,554
# 4                              Slackers       $5,285,941      $6,413,915
# 5                         The Libertine       $4,835,065     $10,852,064
# 6           Madagascar: Escape 2 Africa     $180,010,950    $603,900,354
# 7                               Flipped       $1,755,212      $1,755,212
# 8                        Mansfield Park       $4,775,847      $4,775,847
# 9                       The Dark Knight     $533,345,358  $1,003,845,358
# 10                  Inside Llewyn Davis      $13,235,319     $32,935,319
# 11                                 Kick       $2,472,695     $43,996,483
# 12                  The Perfect Holiday       $5,812,781      $5,812,781
# 13                             The Road       $8,117,000     $27,639,579
# 14                       Pawn Sacrifice       $2,436,633      $5,578,519
# 15                     Mistress America       $2,500,431      $3,340,737
# 16                                Truth       $2,541,854      $5,383,097
# 17                     How to Be Single      $46,843,513    $112,543,513
# 18           The Other Side of the Door       $3,000,342     $14,332,467
# 19                            Compadres       $3,127,773      $7,353,544
#
#                           distributor opening_revenue opening_theaters  \
# 0                        Warner Bros.     $12,174,504            2,905
# 1           Metro-Goldwyn-Mayer (MGM)     $13,049,114            2,675
# 2               Twentieth Century Fox      $1,330,520            1,621
# 3                  Universal Pictures     $18,837,350            3,521
# 4   Sony Pictures Entertainment (SPE)      $2,785,283            1,893
# 5               The Weinstein Company         $27,804                2
# 6                          DreamWorks     $63,106,589            4,056
# 7                        Warner Bros.        $224,233               45
# 8                             Miramax         $85,608                8
# 9                        Warner Bros.    $158,411,483            4,366
# 10                          CBS Films        $405,411                4
# 11                UTV Motion Pictures      $1,071,373              180
# 12          Yari Film Group Releasing      $2,283,360            1,307
# 13                    Dimension Films      $1,502,231              111
# 14              Bleecker Street Media        $202,053               33
# 15                    Fox Searchlight         $93,206                4
# 16             Sony Pictures Classics         $66,232                6
# 17                       Warner Bros.     $17,878,911            3,343
# 18              Twentieth Century Fox      $1,211,210              546
# 19                    Pantelion Films      $1,397,434              368
#
#           budget   MPAA                                  genres in_release  \
# 0    $94,000,000  PG-13                      Action,Drama,Sport        249
# 1    $60,000,000  PG-13                            Comedy,Crime        214
# 2            NaN  PG-13              Action,Drama,Romance,Sport        137
# 3   $100,000,000  PG-13          Action,Adventure,Comedy,Sci-Fi        210
# 4    $14,000,000      R                          Comedy,Romance        334
# 5            NaN      R         Biography,Drama,History,Romance        402
# 6   $150,000,000     PG       Adventure,Animation,Comedy,Family        420
# 7    $14,000,000     PG                    Comedy,Drama,Romance        148
# 8            NaN  PG-13                    Comedy,Drama,Romance        409
# 9   $185,000,000  PG-13             Action,Crime,Drama,Thriller        532
# 10           NaN      R                             Drama,Music        391
# 11           NaN    NaN            Action,Comedy,Crime,Thriller        160
# 12           NaN     PG           Comedy,Family,Fantasy,Romance        386
# 13   $25,000,000      R                          Drama,Thriller        402
# 14           NaN  PG-13  Biography,Drama,History,Sport,Thriller        114
# 15           NaN      R                            Comedy,Drama        147
# 16           NaN      R        Biography,Drama,History,Thriller        443
# 17   $38,000,000      R                    Comedy,Drama,Romance        324
# 18           NaN      R                         Horror,Thriller        303
# 19           NaN      R                     Action,Comedy,Crime        254
#
#    release_date
# 0    27/04/2001
# 1    01/06/2001
# 2    17/08/2005
# 3    05/06/2009
# 4    01/02/2002
# 5           NaN
# 6    07/11/2008
# 7    06/08/2010
# 8    19/11/1999
# 9    18/07/2008
# 10          NaN
# 11   25/07/2014
# 12   12/12/2007
# 13   25/11/2009
# 14          NaN
# 15   14/08/2015
# 16          NaN
# 17   12/02/2016
# 18   04/03/2016
# 19   22/04/2016
